# %%
import pandas as pd
import numpy as np
import datetime
from sqlalchemy import create_engine

# %%
csv_file = "Resources/yelp_academic_dataset_business.csv"

# %%
yelp_df = pd.read_csv(csv_file, error_bad_lines=False)
# Out:
# /Users/gregorymaginn/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (2,5,8,15,18,21,27,30,43,49,52,62,64,66,70,84,89,92,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.DataFrame(yelp_df["business_id"], yelp_df["attributes.Ambience.divey"])
# Out:
#                                       business_id
# attributes.Ambience.divey
# NaN                                           NaN
# False                      vcNAWiLM4dR7D2nwwJ7nCA
# False                      vcNAWiLM4dR7D2nwwJ7nCA
# NaN                                           NaN
# NaN                                           NaN
# ...                                           ...
# False                      vcNAWiLM4dR7D2nwwJ7nCA
# NaN                                           NaN
# NaN                                           NaN
# False                      vcNAWiLM4dR7D2nwwJ7nCA
# NaN                                           NaN
#
# [42153 rows x 1 columns]

# %%
yelp_df.head()
# Out:
#               business_id attributes.Ambience.divey  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA                       NaN
# 1  JwUE5GmEO-sH1FuwJgKBlQ                     False
# 2  uGykseHzyS5xAMWoN6YUqA                     False
# 3  LRKJF43s9-3jG9Lgx4zODg                       NaN
# 4  RgDg-k9S5YD_BaxMckifkg                       NaN
#
#   attributes.Dietary Restrictions.vegan attributes.Happy Hour  \
# 0                                   NaN                   NaN
# 1                                   NaN                   NaN
# 2                                   NaN                   NaN
# 3                                   NaN                   NaN
# 4                                   NaN                   NaN
#
#   hours.Thursday.open attributes.Order at Counter  \
# 0                8:00                         NaN
# 1                 NaN                         NaN
# 2                6:00                         NaN
# 3               10:30                         NaN
# 4               11:00                         NaN
#
#   attributes.Hair Types Specialized In.africanamerican  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   attributes.Hair Types Specialized In.kids attributes.BYOB hours.Friday.open  \
# 0                                       NaN             NaN              8:00
# 1                                       NaN             NaN               NaN
# 2                                       NaN             NaN              6:00
# 3                                       NaN             NaN             10:30
# 4                                       NaN             NaN             11:00
#
#    ... attributes.Smoking  attributes.Attire  \
# 0  ...                NaN                NaN
# 1  ...                NaN             casual
# 2  ...                NaN             casual
# 3  ...                NaN             casual
# 4  ...                NaN             casual
#
#   attributes.Hair Types Specialized In.curly attributes.Good For Groups  \
# 0                                        NaN                        NaN
# 1                                        NaN                       True
# 2                                        NaN                       True
# 3                                        NaN                       True
# 4                                        NaN                        NaN
#
#   neighborhoods attributes.Open 24 Hours attributes.Ambience.romantic  \
# 0           NaN                      NaN                          NaN
# 1           NaN                      NaN                        False
# 2           NaN                      NaN                        False
# 3           NaN                      NaN                          NaN
# 4           NaN                      NaN                          NaN
#
#   attributes.Hair Types Specialized In.perms attributes.Music.jukebox  \
# 0                                        NaN                      NaN
# 1                                        NaN                      NaN
# 2                                        NaN                      NaN
# 3                                        NaN                      NaN
# 4                                        NaN                      NaN
#
#   attributes.Ambience.upscale
# 0                         NaN
# 1                       False
# 2                       False
# 3                         NaN
# 4                         NaN
#
# [5 rows x 105 columns]

# %%
yelp_df.count()

#business_id,attributes.Ambience.divey,attributes.Dietary Restrictions.vegan,
#attributes.Happy Hour,hours.Thursday.open,attributes.Order at Counter,
#attributes.Hair Types Specialized In.africanamerican,
#attributes.Hair Types Specialized In.kids,attributes.BYOB,hours.Friday.open,categories,
#latitude,attributes.Outdoor Seating,attributes.Alcohol,
#attributes.Ambience.classy,attributes.Payment Types.mastercard,
#attributes.Parking.lot,attributes.Ambience.touristy,attributes.Corkage,hours.Tuesday.open,attributes.Good For.brunch,attributes.Payment Types.amex,name,hours.Monday.open,attributes.Waiter Service,attributes.Parking.street,attributes.Ambience.hipster,attributes.BYOB/Corkage,attributes.Hair Types Specialized In.straightperms,attributes.Music.live,attributes.Dietary Restrictions.dairy-free,attributes.Music.background_music,attributes.Price Range,attributes.Good For.breakfast,attributes.Parking.garage,attributes.Music.karaoke,attributes.Good For Dancing,review_count,attributes.Hair Types Specialized In.asian,state,attributes.Accepts Credit Cards,hours.Friday.close,attributes.Good For.lunch,attributes.Good For Kids,attributes.Parking.valet,attributes.Take-out,full_address,hours.Thursday.close,attributes.Hair Types Specialized In.coloring,attributes.Payment Types.cash_only,attributes.Good For.dessert,attributes.Music.video,attributes.Dietary Restrictions.halal,attributes.Takes Reservations,hours.Saturday.open,attributes.Ages Allowed,attributes.Ambience.trendy,attributes.Delivery,hours.Wednesday.close,attributes.Wi-Fi,open,city,attributes.Payment Types.discover,attributes.Wheelchair Accessible,attributes.Dietary Restrictions.gluten-free,stars,attributes.Payment Types.visa,type,attributes.Caters,attributes.Ambience.intimate,attributes.Music.playlist,attributes.Good For.latenight,attributes.Good For.dinner,attributes.Coat Check,longitude,hours.Monday.close,attributes.Hair Types Specialized In.extensions,hours.Tuesday.close,hours.Saturday.close,attributes.Good for Kids,attributes.Parking.validated,hours.Sunday.open,attributes.Accepts Insurance,attributes.Music.dj,attributes.Dietary Restrictions.soy-free,attributes.Has TV,hours.Sunday.close,attributes.Ambience.casual,attributes.By Appointment Only,attributes.Dietary Restrictions.kosher,attributes.Dogs Allowed,attributes.Drive-Thru,attributes.Dietary Restrictions.vegetarian,hours.Wednesday.open,attributes.Noise Level,attributes.Smoking,attributes.Attire,attributes.Hair Types Specialized In.curly,attributes.Good For Groups,neighborhoods,attributes.Open 24 Hours,attributes.Ambience.romantic,attributes.Hair Types Specialized In.perms,attributes.Music.jukebox,attributes.Ambience.upscale
# Out:
# business_id                                   42153
# attributes.Ambience.divey                     11400
# attributes.Dietary Restrictions.vegan           116
# attributes.Happy Hour                          2436
# hours.Thursday.open                           23112
#                                               ...
# attributes.Open 24 Hours                        297
# attributes.Ambience.romantic                  11912
# attributes.Hair Types Specialized In.perms      216
# attributes.Music.jukebox                       2117
# attributes.Ambience.upscale                   11806
# Length: 105, dtype: int64

# %%
groupedlist = yelp_df.groupby(yelp_df.city).count()
groupedlist
# Out:
#                  business_id  attributes.Ambience.divey  \
# city
# Ahwatukee                  8                          3
# Anthem                    63                         18
# Apache Junction           91                         36
# Arcadia                    1                          0
# Atlanta                    1                          0
# ...                      ...                        ...
# Windsor                    7                          1
# Wittmann                   1                          0
# Woolwich                   2                          0
# Youngtown                 14                          3
# chandler                   1                          0
#
#                  attributes.Dietary Restrictions.vegan  attributes.Happy Hour  \
# city
# Ahwatukee                                            0                      1
# Anthem                                               0                      1
# Apache Junction                                      0                      4
# Arcadia                                              0                      0
# Atlanta                                              0                      0
# ...                                                ...                    ...
# Windsor                                              0                      0
# Wittmann                                             0                      0
# Woolwich                                             0                      0
# Youngtown                                            0                      0
# chandler                                             0                      0
#
#                  hours.Thursday.open  attributes.Order at Counter  \
# city
# Ahwatukee                          7                            0
# Anthem                            27                            0
# Apache Junction                   32                            0
# Arcadia                            0                            0
# Atlanta                            1                            0
# ...                              ...                          ...
# Windsor                            4                            0
# Wittmann                           0                            0
# Woolwich                           0                            0
# Youngtown                          8                            0
# chandler                           0                            0
#
#                  attributes.Hair Types Specialized In.africanamerican  \
# city
# Ahwatukee                                                        0
# Anthem                                                           0
# Apache Junction                                                  0
# Arcadia                                                          0
# Atlanta                                                          0
# ...                                                            ...
# Windsor                                                          0
# Wittmann                                                         0
# Woolwich                                                         0
# Youngtown                                                        0
# chandler                                                         0
#
#                  attributes.Hair Types Specialized In.kids  attributes.BYOB  \
# city
# Ahwatukee                                                0                0
# Anthem                                                   0                2
# Apache Junction                                          0                0
# Arcadia                                                  0                0
# Atlanta                                                  0                0
# ...                                                    ...              ...
# Windsor                                                  0                0
# Wittmann                                                 0                0
# Woolwich                                                 0                0
# Youngtown                                                0                0
# chandler                                                 0                0
#
#                  hours.Friday.open  ...  attributes.Smoking  \
# city                                ...
# Ahwatukee                        7  ...                   1
# Anthem                          26  ...                   1
# Apache Junction                 32  ...                   4
# Arcadia                          0  ...                   0
# Atlanta                          1  ...                   0
# ...                            ...  ...                 ...
# Windsor                          4  ...                   0
# Wittmann                         0  ...                   0
# Woolwich                         0  ...                   0
# Youngtown                        8  ...                   0
# chandler                         0  ...                   0
#
#                  attributes.Attire  \
# city
# Ahwatukee                        3
# Anthem                          21
# Apache Junction                 42
# Arcadia                          0
# Atlanta                          1
# ...                            ...
# Windsor                          2
# Wittmann                         0
# Woolwich                         1
# Youngtown                        4
# chandler                         0
#
#                  attributes.Hair Types Specialized In.curly  \
# city
# Ahwatukee                                                 0
# Anthem                                                    0
# Apache Junction                                           0
# Arcadia                                                   0
# Atlanta                                                   0
# ...                                                     ...
# Windsor                                                   0
# Wittmann                                                  0
# Woolwich                                                  0
# Youngtown                                                 0
# chandler                                                  0
#
#                  attributes.Good For Groups  neighborhoods  \
# city
# Ahwatukee                                 3              0
# Anthem                                   22              0
# Apache Junction                          40              0
# Arcadia                                   0              0
# Atlanta                                   1              0
# ...                                     ...            ...
# Windsor                                   2              0
# Wittmann                                  0              0
# Woolwich                                  1              0
# Youngtown                                 4              0
# chandler                                  0              0
#
#                  attributes.Open 24 Hours  attributes.Ambience.romantic  \
# city
# Ahwatukee                               0                             3
# Anthem                                  0                            18
# Apache Junction                         0                            36
# Arcadia                                 0                             0
# Atlanta                                 0                             0
# ...                                   ...                           ...
# Windsor                                 0                             1
# Wittmann                                0                             0
# Woolwich                                0                             0
# Youngtown                               0                             3
# chandler                                0                             0
#
#                  attributes.Hair Types Specialized In.perms  \
# city
# Ahwatukee                                                 0
# Anthem                                                    0
# Apache Junction                                           0
# Arcadia                                                   0
# Atlanta                                                   0
# ...                                                     ...
# Windsor                                                   0
# Wittmann                                                  0
# Woolwich                                                  0
# Youngtown                                                 0
# chandler                                                  0
#
#                  attributes.Music.jukebox  attributes.Ambience.upscale
# city
# Ahwatukee                               1                            3
# Anthem                                  0                           18
# Apache Junction                         4                           36
# Arcadia                                 0                            0
# Atlanta                                 0                            0
# ...                                   ...                          ...
# Windsor                                 0                            1
# Wittmann                                0                            0
# Woolwich                                0                            0
# Youngtown                               0                            3
# chandler                                0                            0
#
# [172 rows x 104 columns]

# %%
bigCities = groupedlist.loc[groupedlist['business_id'] > 1000]

# %%
bigCities.business_id
# Out:
# city
# Chandler       1637
# Edinburgh      2887
# Gilbert        1049
# Glendale       1196
# Henderson      1914
# Las Vegas     12022
# Madison        1630
# Mesa           2041
# Phoenix        7499
# Scottsdale     3605
# Tempe          2025
# Name: business_id, dtype: int64

# %%
Edinburgh_df = yelp_df.loc[yelp_df.city == 'Edinburgh']

# %%
Edinburgh_df
# Out:
#                   business_id attributes.Ambience.divey  \
# 19835  W3THJEcoHZZKgdJJdiFIWw                       NaN
# 19836  aFVO6hoFlOCN8pKsmJbWjw                     False
# 19837  7Iuq-HV4iA5InilfGdjMuw                       NaN
# 19838  2LZtHTbbN5xA3PcPzFsXlQ                     False
# 19839  f_adZ5jM1k9uABuleJmGpw                       NaN
# ...                       ...                       ...
# 42011  lzQb54_a6dhaHzLHA1d_fw                     False
# 42065  ORI4Yt7lQf18z3x1Rih-Tg                     False
# 42125  xT1MO7MLMp3jK4XT1LXiKA                       NaN
# 42142  EYpqqsJZ3L2EFAPK-NEOFA                     False
# 42152  BVxlrYWgmi-8TPGMe6CTpg                       NaN
#
#       attributes.Dietary Restrictions.vegan attributes.Happy Hour  \
# 19835                                   NaN                   NaN
# 19836                                   NaN                 False
# 19837                                   NaN                   NaN
# 19838                                   NaN                   NaN
# 19839                                   NaN                   NaN
# ...                                     ...                   ...
# 42011                                   NaN                 False
# 42065                                   NaN                   NaN
# 42125                                   NaN                   NaN
# 42142                                   NaN                   NaN
# 42152                                   NaN                   NaN
#
#       hours.Thursday.open attributes.Order at Counter  \
# 19835                 NaN                         NaN
# 19836               12:00                         NaN
# 19837                8:30                         NaN
# 19838               12:00                         NaN
# 19839                 NaN                         NaN
# ...                   ...                         ...
# 42011                8:00                         NaN
# 42065               18:00                         NaN
# 42125                 NaN                         NaN
# 42142               12:00                         NaN
# 42152                 NaN                         NaN
#
#       attributes.Hair Types Specialized In.africanamerican  \
# 19835                                                NaN
# 19836                                                NaN
# 19837                                                NaN
# 19838                                                NaN
# 19839                                                NaN
# ...                                                  ...
# 42011                                                NaN
# 42065                                                NaN
# 42125                                                NaN
# 42142                                                NaN
# 42152                                                NaN
#
#       attributes.Hair Types Specialized In.kids attributes.BYOB  \
# 19835                                       NaN             NaN
# 19836                                       NaN             NaN
# 19837                                       NaN             NaN
# 19838                                       NaN             NaN
# 19839                                       NaN             NaN
# ...                                         ...             ...
# 42011                                       NaN             NaN
# 42065                                       NaN             NaN
# 42125                                       NaN             NaN
# 42142                                       NaN             NaN
# 42152                                       NaN             NaN
#
#       hours.Friday.open  ... attributes.Smoking  attributes.Attire  \
# 19835               NaN  ...                NaN                NaN
# 19836             12:00  ...                 no             casual
# 19837              8:30  ...                NaN                NaN
# 19838             12:00  ...                 no                NaN
# 19839               NaN  ...                NaN                NaN
# ...                 ...  ...                ...                ...
# 42011              8:00  ...            outdoor             casual
# 42065             12:00  ...                NaN             casual
# 42125               NaN  ...                NaN                NaN
# 42142             12:00  ...                NaN             casual
# 42152               NaN  ...                NaN                NaN
#
#       attributes.Hair Types Specialized In.curly attributes.Good For Groups  \
# 19835                                        NaN                        NaN
# 19836                                        NaN                       True
# 19837                                        NaN                        NaN
# 19838                                        NaN                       True
# 19839                                        NaN                       True
# ...                                          ...                        ...
# 42011                                        NaN                       True
# 42065                                        NaN                        NaN
# 42125                                        NaN                       True
# 42142                                        NaN                       True
# 42152                                        NaN                        NaN
#
#                        neighborhoods attributes.Open 24 Hours  \
# 19835              West End;New Town                      NaN
# 19836            Old Town;Royal Mile                      NaN
# 19837                          Leith                      NaN
# 19838                       New Town                      NaN
# 19839  Newington;Old Town;Royal Mile                      NaN
# ...                              ...                      ...
# 42011           Grassmarket;Old Town                      NaN
# 42065                            NaN                      NaN
# 42125                          Leith                      NaN
# 42142                       New Town                      NaN
# 42152             Tollcross;Old Town                      NaN
#
#       attributes.Ambience.romantic attributes.Hair Types Specialized In.perms  \
# 19835                          NaN                                        NaN
# 19836                        False                                        NaN
# 19837                          NaN                                        NaN
# 19838                        False                                        NaN
# 19839                          NaN                                        NaN
# ...                            ...                                        ...
# 42011                        False                                        NaN
# 42065                        False                                        NaN
# 42125                          NaN                                        NaN
# 42142                        False                                        NaN
# 42152                          NaN                                        NaN
#
#       attributes.Music.jukebox attributes.Ambience.upscale
# 19835                      NaN                         NaN
# 19836                      NaN                       False
# 19837                      NaN                         NaN
# 19838                     True                       False
# 19839                      NaN                         NaN
# ...                        ...                         ...
# 42011                      NaN                       False
# 42065                      NaN                       False
# 42125                      NaN                         NaN
# 42142                      NaN                       False
# 42152                      NaN                         NaN
#
# [2887 rows x 105 columns]
